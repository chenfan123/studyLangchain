# %%
import os
from dotenv import load_dotenv
from langchain_qwq import ChatQwen
from rich import print as rprint

# 将env文件中的变量加载为环境变量
#override=True：表示.env优先
load_dotenv(override=True)

model = ChatQwen(
    model="deepseek-v4-flash",
    api_base=os.getenv("DASHSCOPE_API_BASE"),  # 国内 Key 必须用国内地址
)
rprint(model.invoke("你好,请想一句诗"))
# Out:
# AIMessage(
#     content='好的，这句诗送给你：\n\n**“面朝大海，春暖花开”**\n\n这是诗人海子最经典的诗句。它不仅有开阔的意境，更寄
# 托了对自由、温暖和美好生活的向往，愿它能为你带来一份宁静与希望。',
#     additional_kwargs={
#         'refusal': None,
#         'reasoning_content':
# '嗯，用户让我想一句诗。这是一个比较简单的请求，用户没有指定主题、风格或朝代，只是要一句诗。考虑到直接创作一句古风诗
# 可能对用户来说不够通用，且古典诗词浩如烟海，我很难确定用户的具体偏好。\n\n或许可以提供一个高适配度的选项。海子的“面
# 朝大海，春暖花开”流传很广，意境开阔、温暖，能引发很多人的共鸣，而且这句话本身已经具有诗的美感和独立性。它既适合单独
# 品味，也适合各种场景引用。\n\n想到了，就推荐这句，并解释一下它的意境和适用性，这样既完成了用户的指令，也给了用户一
# 个清晰、有价值的回应。'
#     },
#     response_metadata={
#         'token_usage': {
#             'completion_tokens': 195,
#             'prompt_tokens': 10,
#             'total_tokens': 205,
#             'completion_tokens_details': {
#                 'accepted_prediction_tokens': None,
#                 'audio_tokens': None,
#                 'reasoning_tokens': 141,
#                 'rejected_prediction_tokens': None
#             },
#             'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}
#         },
#         'model_provider': 'dashscope',
#         'model_name': 'deepseek-v4-flash',
#         'system_fingerprint': None,
#         'id': 'chatcmpl-7f43e063-ec86-9cd8-bb2b-4e8704456b40',
#         'finish_reason': 'stop',
#         'logprobs': None
#     },
#     id='lc_run--019f0a23-a5de-7240-a7f7-244e727d614b-0',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     usage_metadata={
#         'input_tokens': 10,
#         'output_tokens': 195,
#         'total_tokens': 205,
#         'input_token_details': {'cache_read': 0},
#         'output_token_details': {'reasoning': 141}
#     }
# )

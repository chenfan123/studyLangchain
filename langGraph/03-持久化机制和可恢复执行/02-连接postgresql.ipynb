# %%
import psycopg

DB_URL = "postgresql://agent_user:agent_password@localhost:5432/agent_db?sslmode=disable"
conn = psycopg.connect(DB_URL)
cur = conn.cursor()

# 查看 PostgreSQL 版本信息
cur.execute("SELECT version();")
result = cur.fetchone()
print(f"PostgreSQL 版本：{result[0]}")

cur.close()
conn.close()
# Out:
# PostgreSQL 版本：PostgreSQL 18.4 on aarch64-unknown-linux-musl, compiled by gcc (Alpine 15.2.0) 15.2.0, 64-bit
